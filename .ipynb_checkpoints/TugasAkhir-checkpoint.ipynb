# %%
def updateData():
    import tweepy as tp
    import re
    import string
    import pandas as pd
    from datetime import datetime, timedelta
    from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
    from sqlalchemy import create_engine
        
    consumer_key = 'D7Ch0N24KVqLpwk7jVgwbNHtT'
    consumer_secret = 'hrqTxd1tueHNuEmdwqNtXPyplHYpgYIOJRGw662NyIu6sYYsPD'
    access_token = '1288033810722852869-zJeJ6zkxdhFuHpgLRhTd5NhLcmygNh'
    access_token_secret = '6TNEDjmX4kTl0UFNFRpZoGb3p2D5TycvZ9d6hh9pK2Lia'
    
    auth = tp.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    api = tp.API(auth)
        
    keyword = 'vaksin covid'
    newKeyword = keyword + " -filter:retweets"
    ndays=2
    dateRange = datetime.now() - timedelta(days=ndays)
    date_since = dateRange.strftime('%Y-%m-%d')
    date_now = (datetime.now() + timedelta(days=1)).strftime('%Y-%m-%d')
        
    tweets = tp.Cursor(api.search, q=newKeyword, lang="id", since=date_since, until=date_now,tweet_mode="extended").items(1000)
#     tweets = api.search(q=newKeyword, lang='id', until=date_now, since=date_since, tweet_mode='extended')
    items = []
    
    for tweet in tweets:
        item = []
        sn = tweet.user.screen_name
        date = tweet.created_at
        text = tweet.full_text #get full text
        text = text.strip() #remove empty char
        text = text.lower() #to lowercase
        text = re.sub(r"\d+", "", text) #remove number
        text = text.translate(str.maketrans('', '', string.punctuation)) #remove punctuation
        factory = StopWordRemoverFactory()
        stopword = factory.create_stop_word_remover()
        text = stopword.remove(text)
        item.append(sn)
        item.append(text)
        item.append(date.strftime('%Y-%m-%d'))
        item.append('-')
        items.append(item)
    
    pd.options.display.max_colwidth = 300
    df = pd.DataFrame(data=items, columns=['user', 'tweet', 'date', 'sentiment'])
    
    engine = create_engine('sqlite:///TugasAkhirDataScience.db', echo=True)
    sqlite_connection = engine.connect()
    
    sqlite_table = "tweet_data"
    df.to_sql(sqlite_table, sqlite_connection, if_exists='append', index=False)

# %%
updateData()
# Out:
# 2020-08-12 21:16:36,022 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-08-12 21:16:36,024 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:16:36,026 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-08-12 21:16:36,029 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:16:36,035 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("tweet_data")
# 2020-08-12 21:16:36,037 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:16:36,041 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-08-12 21:16:36,053 INFO sqlalchemy.engine.base.Engine INSERT INTO tweet_data (user, tweet, date, sentiment) VALUES (?, ?, ?, ?)
# 2020-08-12 21:16:36,061 INFO sqlalchemy.engine.base.Engine (('pakguruhonorer', 'rusia  memproduksi vaksin buatannya bulan september  nama sputnikv\nhttpstcownaoyt', '2020-08-12', '-'), ('betinagarang', 'subtanyarl de besok aa kerumah mau ketemu papa terus lamar dede \nbreaking news covid hilang sudah vaksin nya\nini yg paling ditunggu🥰🥰', '2020-08-12', '-'), ('jurnascom', 'menkes murashko tepis keraguan kemampuan vaksin covid  rusia httpstcoeghywhiiy httpstcodhhnbzani', '2020-08-12', '-'), ('irmawindya', 'dheejhe mobil haluu nasib vaksin covid kuatir nya ga jauh dari', '2020-08-12', '-'), ('SulSelSatu', 'bio farma suntikan dana rp t pengembangan vaksin covid httpstcobmwqdgwe httpstcocqamizzpjv', '2020-08-12', '-'), ('Mr_Didie01', 'bio farma suntikan dana rp t pengembangan vaksin covid httpstcoggaryawcc httpstcozxuymtfng', '2020-08-12', '-'), ('younghotyelloe', 'subtanyarl indonesia dinyatakan bersih dri covid kehidupan kmbali normal vaksin virus tersebut telah temukan', '2020-08-12', '-'), ('SINDOnews', 'erick thohir vaksin covid membuat tidak terbebani terjebak psbb httpstcovawqndze', '2020-08-12', '-')  ... displaying 10 of 631 total bound parameter sets ...  ('republikaonline', 'penasihat senior gedung mengatakan trump umumkan perkembangan vaksin httpstcojjpavtbtl', '2020-08-12', '-'), ('melakafm', 'moscow  ogos \xa0 vaksin pertama dunia didaftarkan merawat covid dibangunkan rusia diberi nama sputnik v memetik laman web rasmi vaksin\xa0 selasa\n\npada  kejayaan pelancaran… httpstconxzkxrijlx', '2020-08-12', '-'))
# 2020-08-12 21:16:36,112 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
def updateSentiment():
    import sqlalchemy as db
    import pandas as pd
    
    engine = db.create_engine('sqlite:///TugasAkhirDataScience.db', echo=True)
    sqlite_connection = engine.connect()
    metadata = db.MetaData()
    tweet_data = db.Table('tweet_data', metadata, autoload=True, autoload_with=engine)
    query = db.select([tweet_data])
    ResultProxy = sqlite_connection.execute(query)
    ResultSet = ResultProxy.fetchall()
    
    df = pd.DataFrame(ResultSet)
    df.columns = ResultSet[0].keys()
    df = df.drop_duplicates(subset='tweet', keep='first')
    
    pos_list= open("kata_positif.txt","r")
    pos_kata = pos_list.readlines()
    neg_list= open("kata_negatif.txt","r")
    neg_kata = neg_list.readlines()
    
    s = []
    for index, data in df.iterrows():
        count_p = 0
        count_n = 0
        for kata_pos in pos_kata:
            if kata_pos.strip() in data['tweet']:
                count_p +=1
        for kata_neg in neg_kata:
            if kata_neg.strip() in data['tweet']:
                count_n +=1
        sentiment = count_p - count_n
        s.append(sentiment)
        
    df['sentiment'] = s
    
    sqlite_table = "tweet_sentiment"
    df.to_sql(sqlite_table, sqlite_connection, if_exists='replace', index=False)
    
    with engine.begin() as cn:
        sql = """INSERT INTO tweet_sentiment (user, tweet, date, sentiment)
            SELECT t.user, t.tweet, t.date, t.sentiment
            FROM myTempTable t
            WHERE NOT EXISTS 
                (SELECT 1 FROM myFinalTable f
                 WHERE t.user = f.user
                 AND t.tweet = f.tweet)"""

        cn.execute(sql)

# %%
updateSentiment()
# Out:
# 2020-08-12 21:40:10,122 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-08-12 21:40:10,124 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:40:10,128 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-08-12 21:40:10,131 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:40:10,135 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("tweet_data")
# 2020-08-12 21:40:10,138 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:40:10,142 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'tweet_data' AND type = 'table'
# 2020-08-12 21:40:10,145 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:40:10,148 INFO sqlalchemy.engine.base.Engine PRAGMA main.foreign_key_list("tweet_data")
# 2020-08-12 21:40:10,151 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:40:10,154 INFO sqlalchemy.engine.base.Engine PRAGMA temp.foreign_key_list("tweet_data")
# 2020-08-12 21:40:10,157 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:40:10,159 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'tweet_data' AND type = 'table'
# 2020-08-12 21:40:10,160 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:40:10,163 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("tweet_data")
# 2020-08-12 21:40:10,165 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:40:10,168 INFO sqlalchemy.engine.base.Engine PRAGMA temp.index_list("tweet_data")
# 2020-08-12 21:40:10,171 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:40:10,173 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("tweet_data")
# 2020-08-12 21:40:10,174 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:40:10,177 INFO sqlalchemy.engine.base.Engine PRAGMA temp.index_list("tweet_data")
# 2020-08-12 21:40:10,186 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:40:10,189 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'tweet_data' AND type = 'table'
# 2020-08-12 21:40:10,191 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:40:10,195 INFO sqlalchemy.engine.base.Engine SELECT tweet_data.user, tweet_data.tweet, tweet_data.date, tweet_data.sentiment
# FROM tweet_data
# 2020-08-12 21:40:10,197 INFO sqlalchemy.engine.base.Engine ()
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-37ded289c7fe> in <module>
# ----> 1 updateSentiment()
#
# <ipython-input-18-64fc4f39db23> in updateSentiment()
#      36
#      37     sqlite_table = "tweet_sentiment"
# ---> 38     df.to_sql(sqlite_table, sqlite_connection, if_exists='replace', dtype={date: DATETIME for date in df}, index=False)
#      39
#      40     with engine.begin() as cn:
#
# <ipython-input-18-64fc4f39db23> in <dictcomp>(.0)
#      36
#      37     sqlite_table = "tweet_sentiment"
# ---> 38     df.to_sql(sqlite_table, sqlite_connection, if_exists='replace', dtype={date: DATETIME for date in df}, index=False)
#      39
#      40     with engine.begin() as cn:
#
# NameError: name 'DATETIME' is not defined

# %%
def lihatData(since, until):
    import sqlalchemy as db
    import pandas as pd
    
    engine = db.create_engine('sqlite:///TugasAkhirDataScience.db', echo=True)
    sqlite_connection = engine.connect()
    metadata = db.MetaData()
    tweet_sentiment = db.Table('tweet_sentiment', metadata, autoload=True, autoload_with=engine)
    query = db.select([tweet_sentiment])
    
    ResultProxy = sqlite_connection.execute(query)
    ResultSet = ResultProxy.fetchall()
    
    df = pd.DataFrame(ResultSet)
    return df

# %%
da = lihatData()
da
# Out:
# 2020-08-12 21:20:29,067 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-08-12 21:20:29,069 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:20:29,072 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-08-12 21:20:29,074 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:20:29,078 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("tweet_sentiment")
# 2020-08-12 21:20:29,081 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:20:29,085 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'tweet_sentiment' AND type = 'table'
# 2020-08-12 21:20:29,087 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:20:29,090 INFO sqlalchemy.engine.base.Engine PRAGMA main.foreign_key_list("tweet_sentiment")
# 2020-08-12 21:20:29,093 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:20:29,095 INFO sqlalchemy.engine.base.Engine PRAGMA temp.foreign_key_list("tweet_sentiment")
# 2020-08-12 21:20:29,098 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:20:29,101 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'tweet_sentiment' AND type = 'table'
# 2020-08-12 21:20:29,102 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:20:29,105 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("tweet_sentiment")
# 2020-08-12 21:20:29,106 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:20:29,109 INFO sqlalchemy.engine.base.Engine PRAGMA temp.index_list("tweet_sentiment")
# 2020-08-12 21:20:29,111 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:20:29,112 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("tweet_sentiment")
# 2020-08-12 21:20:29,113 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:20:29,116 INFO sqlalchemy.engine.base.Engine PRAGMA temp.index_list("tweet_sentiment")
# 2020-08-12 21:20:29,117 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:20:29,119 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'tweet_sentiment' AND type = 'table'
# 2020-08-12 21:20:29,120 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-12 21:20:29,125 INFO sqlalchemy.engine.base.Engine SELECT tweet_sentiment.user, tweet_sentiment.tweet, tweet_sentiment.date, tweet_sentiment.sentiment
# FROM tweet_sentiment
# 2020-08-12 21:20:29,134 INFO sqlalchemy.engine.base.Engine ()
#                    0  \
# 0    rahmatsyahlubi1
# 1       Mjohnsamosir
# 2        IwanBotak19
# 3    republikaonline
# 4    ForpisKarangan1
# ..               ...
# 640          uknee11
# 641      NurahmaTity
# 642   ElshintaDotcom
# 643  republikaonline
# 644         melakafm
#
#                                                                                                                                                                                                                                                              1  \
# 0            disaat presiden duterte putri presiden rusia menjadi relawan vaksin covid  buatan rusia indonesia malah mentrinya menyuruh rakyatnya maju deluan presidennya membiarkan anak menantunya ikut bertarung pilkada\nnkri harga nego\nhttpstcoeopbvgpf
# 1                                                                                                                         kompastv ridwankamil hebat memang gubernur jawa barat ridwan kamil cuma bicara langsung memberi contoh ikut relawan uji vaksin covid
# 2                                                                                                                                                                                                      vivacoid achmadkonie vaksin covid buatan china mau dur
# 3                                                                                                                                                                          vaksin sputnik v diberikan puluhan ribu guru tenaga kesehatan rusia httpstcoodrmmxm
# 4        ilmuwan diseluruh dunia sedang berupaya membuat vaksin covid \nsampai itu lakukan teratur  langkah perlindungan cegahcovid pakaimasker jagajarakaman cucitanganpakaisabun\nkitahadapibersama maskeruntuksemua jagadiri sayadutasehat httpstcobyxqtsfl
# ..                                                                                                                                                                                                                                                         ...
# 640           kunjungan presiden clin trial fase  vaksin covid kemarin berpengaruh penelitian pengembangan vaksin dilakukan konsorsium nasionalhal penting yg diperhatikan\ndi indonesia sejak bbrp tahun lalu diprakarsai kemenristek konsorsium life science
# 641  luar biasa ridwankamil mendaftar jadi relawan uji klinis vaksin covid\nberani digarda terdepan jabar juara\n\npplhiupdate jabarjuaralahirbatin rkjabarjuara jabarterbaiktanganicovid humasjabar \n\nridwankamil ramrammukhlis fhmymchtr httpstcokxnatmprh
# 642                                                                                                                                                    as teken kontrak pembelian vaksin covid moderna senilai rp triliun\nhttpstcorjcwqoezuh httpstcoeutwngwa
# 643                                                                                                                                                                     penasihat senior gedung mengatakan trump umumkan perkembangan vaksin httpstcojjpavtbtl
# 644                                                              moscow  ogos   vaksin pertama dunia didaftarkan merawat covid dibangunkan rusia diberi nama sputnik v memetik laman web rasmi vaksin  selasa\n\npada  kejayaan pelancaran… httpstconxzkxrijlx
#
#               2  3
# 0    2020-08-11  0
# 1    2020-08-11  0
# 2    2020-08-11 -1
# 3    2020-08-11  2
# 4    2020-08-11  2
# ..          ... ..
# 640  2020-08-12  3
# 641  2020-08-12  8
# 642  2020-08-12 -1
# 643  2020-08-12  0
# 644  2020-08-12  4
#
# [645 rows x 4 columns]

# %%
def visualize():
